# %%
import quandl
import pymongo
from pymongo import MongoClient
import pandas as pd

# %%
df = pd.read_json("songs.json", orient="records")

# %%
df
# Out:
#                                          song  mod  \
# 0                                     Deserto    1
# 1                             Pode Morar Aqui    2
# 2                             A Maior Saudade    2
# 3                                  Evidências    2
# 4                               Vem Me Buscar    2
# ..                                        ...  ...
# 991                          Cordeiro de Deus    2
# 992                              Ovelha Negra    2
# 993                                 Relicário    2
# 994                                    Sparks    2
# 995  Cê Tá Preparada (part. Marília Mendonça)    1
#
#                          artist             genre  \
# 0                  Maria Marçal  Gospel/Religioso
# 1                    Theo Rubia  Gospel/Religioso
# 2            Henrique e Juliano         Sertanejo
# 3          Chitãozinho & Xororó         Sertanejo
# 4           Jefferson & Suellen  Gospel/Religioso
# ..                          ...               ...
# 991  Comunidade Católica Shalom  Gospel/Religioso
# 992                    Rita Lee     Rock and Roll
# 993                  Nando Reis               MPB
# 994                    Coldplay          Pop Rock
# 995                     Tayrone              None
#
#                                                 chords
# 0    [A, B, B/D#, C#m7, E, E9, F#, F#/A#, F#4, F#4(...
# 1                   [Am7*, C*, C/E*, Em*, F*, G*, G4*]
# 2                          [Am*, C*, Dm*, Em*, F*, G*]
# 3    [A, A/B, A/C#, Am, B, B/D#, B7, C#7, C#m, C#m7...
# 4    [A*, A11*, A9*, Bm*, Bm11*, Bm6(11)*, D9/F#*, ...
# ..                                                 ...
# 991  [Am, Bm, C, C#m7(5-), C/E, C7M, D, D#º, D/F#, ...
# 992                 [A, C, D, E, E4(7), E7, F, F#m, G]
# 993  [A7, C, D, D/C, D/F#, D5+, D6, D7, Em, Em/F#, ...
# 994            [Am*, C7M*, Em*, Em6*, Em7M*, G*, G7M*]
# 995                                  [A, Bm, D, Em, G]
#
# [996 rows x 5 columns]

# %%
# Making a Connection with MongoClient

client = MongoClient("mongodb+srv://rusbe:rusbezim@cinfra-club.csmendp.mongodb.net/?retryWrites=true&w=majority")

# database
db = client["cinfraClub"]
# collection
collection= db["songs"]

data_dict = df.to_dict("records")
#Insert collection in database
collection.insert_many(data_dict)
