# %%
import quandl
import pymongo
from pymongo import MongoClient
import pandas as pd

# %%
df = pd.read_json("songs.json", orient="records")

# %%
df
# Out:
#                               song  mod           artist        genre  \
# 0                       Anna Júlia    2     Los Hermanos  Alternativo
# 1                            Creep    2        Radiohead  Alternativo
# 2           Somewhere Only We Know    1            Keane  Alternativo
# 3                         Atlantis    1          Seafret  Alternativo
# 4               Losing My Religion    2           R.E.M.  Alternativo
# ...                            ...  ...              ...          ...
# 16594               Tão Apaixonado    2  Irmãos Verdades         Zouk
# 16595                  Não Me Pede    2         C4 Pedro         Zouk
# 16596                      Tá Malé    2   Puto Português         Zouk
# 16597           De Maria Pra Meury    2   Puto Português         Zouk
# 16598  Dessa Vez (feat. Gabeladas)    2   Puto Português         Zouk
#
#                                                   chords  \
# 0                          [A*, B*, C#m*, E*, G#*, G#m*]
# 1                                          [B, C, Cm, G]
# 2      [A, A/C#, A9, Bm, Bm/D, Bm7, C#m, C#m/E, Cm, D...
# 3                                   [B, C#m, E, F#, G#m]
# 4           [A9*, Am*, Bm*, C*, D*, D9*, Em*, Em/B*, G*]
# ...                                                  ...
# 16594                                [Am, Dm, Dm6, F, G]
# 16595                                 [Am, C, D, Em, G7]
# 16596                                   [A7, B9, C9, Dm]
# 16597                                          [Bm, F#7]
# 16598                              [A, A7M, B, C#m, G#m]
#
#                                                      url
# 0      https://cifraclub.com.br/los-hermanos/anna-jul...
# 1      https://cifraclub.com.br/radiohead/creep/#inst...
# 2      https://cifraclub.com.br/keane/somewhere-only-...
# 3      https://cifraclub.com.br/seafret/atlantis/#ins...
# 4      https://cifraclub.com.br/rem/losing-my-religio...
# ...                                                  ...
# 16594  https://cifraclub.com.br/irmaos-verdades/tao-a...
# 16595  https://cifraclub.com.br/c4-pedro/nao-me-pede/...
# 16596  https://cifraclub.com.br/puto-portugues/ta-mal...
# 16597  https://cifraclub.com.br/puto-portugues/de-mar...
# 16598  https://cifraclub.com.br/puto-portugues/dessa-...
#
# [16599 rows x 6 columns]

# %%
# Making a Connection with MongoClient

client = MongoClient("mongodb+srv://rusbe:rusbezim@cinfra-club.csmendp.mongodb.net/?retryWrites=true&w=majority")

# database
db = client["cinfraClub"]
# collection
collection= db["songs"]

data_dict = df.to_dict("records")
#Insert collection in database
collection.insert_many(data_dict)
