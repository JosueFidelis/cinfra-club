# %%
import requests
import pandas as pd
import json

# %% [markdown]
# # GET SONGS

# %%
url = "https://api.cifraclub.com.br/v3/tops?genre=all&" +\
  "instrument=guitar&" +\
  "period=semana&" +\
  "limitSongs=1000&" +\
  "limitArtists=0" +\
  "&offsetSongs=0&" +\
  "offsetArtists=0"

payload={}
headers = {
  'Accept': '*/*',
  'Accept-Language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,ja-JP;q=0.6,ja;q=0.5',
  'Connection': 'keep-alive',
  'Origin': 'https://www.cifraclub.com.br',
  'Referer': 'https://www.cifraclub.com.br/',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-site',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36',
  'X-Authorization': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..KYuZCi4m_vabxOjgo9R3xF7FxagBQZuKNp9jcxAh5Z3U61KxrhaJb9AeQ9TNYfW0C8WzkK3x0Vj3efIVhCqRCXdDRF9QTNChrt7SOApUxvJmwD9oO5BVx2DK_0M1-xJ3yrgrDIPq_3cjPeVT9erwYo70V9h35UGXue8xE_m2YLiOWH5w8XCd6ZfpHkeScu-OrreX3RgXQamXSLaXdY-alTEogCJVhHkO0qNcvStzdFoAvwLuNfbB3_pkIki3aShjhQ_E6f6kfUxoqhkYZNY8b394IaSrZ5P0S9u81X1LoMA_xSY-PARa5fYnMsNmEWEi57WL9bSrCaG9RkuUJ3dz6w',
  'sec-ch-ua': '"Chromium";v="106", "Google Chrome";v="106", "Not;A=Brand";v="99"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

response = requests.request("GET", url, headers=headers, data=payload)

# %%
json_res = response.json()

# %%
df_songs = pd.DataFrame(json_res["songs"])
df_songs
# Out:
#          id                                               name  \
# 0    738834                                            Deserto
# 1    475833                                    Pode Morar Aqui
# 2    716152                                    A Maior Saudade
# 3      1906                                         Evidências
# 4    724683                                      Vem Me Buscar
# ..      ...                                                ...
# 995   11461                             Outra Noite Que Se Vai
# 996  736904                                         Estrelinha
# 997  492785  Te Amar Foi Ilusão / Passou da Conta / Convite...
# 998  170428                             Quero Ser Como Criança
# 999    3386                                   Lágrimas e Chuva
#
#                                                    url  \
# 0                                              deserto
# 1                                      pode-morar-aqui
# 2                                      a-maior-saudade
# 3                                           evidencias
# 4                                        vem-me-buscar
# ..                                                 ...
# 995                             outra-noite-que-se-vai
# 996                                         estrelinha
# 997  te-amar-foi-ilusao-passou-da-conta-convite-de-...
# 998                             quero-ser-como-crianca
# 999                                     lagrimas-chuva
#
#                                                 artist    hits         mod
# 0    {'id': 321205, 'name': 'Maria Marçal', 'url': ...  124060    revisada
# 1    {'id': 156142, 'name': 'Theo Rubia', 'url': 't...   86089  video-aula
# 2    {'id': 127408, 'name': 'Henrique e Juliano', '...   64173  video-aula
# 3    {'id': 6956, 'name': 'Chitãozinho & Xororó', '...   59540  video-aula
# 4    {'id': 263513, 'name': 'Jefferson & Suellen', ...   54731  video-aula
# ..                                                 ...     ...         ...
# 995  {'id': 9022, 'name': 'Armandinho', 'url': 'arm...    2715    revisada
# 996  {'id': 15576, 'name': 'Di Paullo e Paulino', '...    2713
# 997  {'id': 132057, 'name': 'Hugo e Guilherme', 'ur...    2712
# 998  {'id': 21491, 'name': 'Heloísa Rosa', 'url': '...    2710    revisada
# 999  {'id': 2, 'name': 'Kid Abelha', 'url': 'kid-ab...    2708  video-aula
#
# [1000 rows x 6 columns]

# %%
df_songs["pandas_id"] = df_songs.index
df_songs.set_index("pandas_id", inplace=True)
df_songs
# Out:
#                id                                               name  \
# pandas_id
# 0          738834                                            Deserto
# 1          475833                                    Pode Morar Aqui
# 2          716152                                    A Maior Saudade
# 3            1906                                         Evidências
# 4          724683                                      Vem Me Buscar
# ...           ...                                                ...
# 995         11461                             Outra Noite Que Se Vai
# 996        736904                                         Estrelinha
# 997        492785  Te Amar Foi Ilusão / Passou da Conta / Convite...
# 998        170428                             Quero Ser Como Criança
# 999          3386                                   Lágrimas e Chuva
#
#                                                          url  \
# pandas_id
# 0                                                    deserto
# 1                                            pode-morar-aqui
# 2                                            a-maior-saudade
# 3                                                 evidencias
# 4                                              vem-me-buscar
# ...                                                      ...
# 995                                   outra-noite-que-se-vai
# 996                                               estrelinha
# 997        te-amar-foi-ilusao-passou-da-conta-convite-de-...
# 998                                   quero-ser-como-crianca
# 999                                           lagrimas-chuva
#
#                                                       artist    hits  \
# pandas_id
# 0          {'id': 321205, 'name': 'Maria Marçal', 'url': ...  124060
# 1          {'id': 156142, 'name': 'Theo Rubia', 'url': 't...   86089
# 2          {'id': 127408, 'name': 'Henrique e Juliano', '...   64173
# 3          {'id': 6956, 'name': 'Chitãozinho & Xororó', '...   59540
# 4          {'id': 263513, 'name': 'Jefferson & Suellen', ...   54731
# ...                                                      ...     ...
# 995        {'id': 9022, 'name': 'Armandinho', 'url': 'arm...    2715
# 996        {'id': 15576, 'name': 'Di Paullo e Paulino', '...    2713
# 997        {'id': 132057, 'name': 'Hugo e Guilherme', 'ur...    2712
# 998        {'id': 21491, 'name': 'Heloísa Rosa', 'url': '...    2710
# 999        {'id': 2, 'name': 'Kid Abelha', 'url': 'kid-ab...    2708
#
#                   mod
# pandas_id
# 0            revisada
# 1          video-aula
# 2          video-aula
# 3          video-aula
# 4          video-aula
# ...               ...
# 995          revisada
# 996
# 997
# 998          revisada
# 999        video-aula
#
# [1000 rows x 6 columns]

# %%
df_artist = pd.json_normalize(df_songs.artist)
df_artist
# Out:
#          id                  name                   url  totalPhotos  \
# 0    321205          Maria Marçal          maria-marcal            1
# 1    156142            Theo Rubia            theo-rubia            4
# 2    127408    Henrique e Juliano    henrique-e-juliano           51
# 3      6956  Chitãozinho & Xororó  chitaozinho-e-xororo          123
# 4    263513   Jefferson & Suellen   jefferson-e-suellen            4
# ..      ...                   ...                   ...          ...
# 995    9022            Armandinho            armandinho           18
# 996   15576   Di Paullo e Paulino    di-paulo-e-paulino            2
# 997  132057      Hugo e Guilherme        hugo-guilherme            2
# 998   21491          Heloísa Rosa          heloisa-rosa           10
# 999       2            Kid Abelha            kid-abelha           12
#
#     headImage songs  genre.id        genre.name        genre.url  \
# 0        None  None      30.0  Gospel/Religioso  gospelreligioso
# 1        None  None      30.0  Gospel/Religioso  gospelreligioso
# 2        None  None       9.0         Sertanejo        sertanejo
# 3        None  None       9.0         Sertanejo        sertanejo
# 4        None  None      30.0  Gospel/Religioso  gospelreligioso
# ..        ...   ...       ...               ...              ...
# 995      None  None      13.0            Reggae           reggae
# 996      None  None       9.0         Sertanejo        sertanejo
# 997      None  None       9.0         Sertanejo        sertanejo
# 998      None  None      30.0  Gospel/Religioso  gospelreligioso
# 999      None  None       2.0          Pop Rock          poprock
#
#                                               image.50  \
# 0    https://akamai.sscdn.co/letras/50x50/fotos/5/6...
# 1    https://akamai.sscdn.co/letras/50x50/fotos/7/a...
# 2    https://akamai.sscdn.co/letras/50x50/fotos/a/f...
# 3    https://akamai.sscdn.co/letras/50x50/fotos/9/a...
# 4    https://akamai.sscdn.co/letras/50x50/fotos/4/7...
# ..                                                 ...
# 995  https://akamai.sscdn.co/letras/50x50/fotos/9/9...
# 996  https://akamai.sscdn.co/letras/50x50/fotos/1/7...
# 997  https://akamai.sscdn.co/letras/50x50/fotos/5/4...
# 998  https://akamai.sscdn.co/letras/50x50/fotos/0/8...
# 999  https://akamai.sscdn.co/letras/50x50/fotos/7/5...
#
#                                              image.162  \
# 0    https://akamai.sscdn.co/letras/162x162/fotos/5...
# 1    https://akamai.sscdn.co/letras/162x162/fotos/7...
# 2    https://akamai.sscdn.co/letras/162x162/fotos/a...
# 3    https://akamai.sscdn.co/letras/162x162/fotos/9...
# 4    https://akamai.sscdn.co/letras/162x162/fotos/4...
# ..                                                 ...
# 995  https://akamai.sscdn.co/letras/162x162/fotos/9...
# 996  https://akamai.sscdn.co/letras/162x162/fotos/1...
# 997  https://akamai.sscdn.co/letras/162x162/fotos/5...
# 998  https://akamai.sscdn.co/letras/162x162/fotos/0...
# 999  https://akamai.sscdn.co/letras/162x162/fotos/7...
#
#                                              image.250 image.color  \
# 0    https://akamai.sscdn.co/letras/250x250/fotos/5...     #387ED6
# 1    https://akamai.sscdn.co/letras/250x250/fotos/7...     #D76432
# 2    https://akamai.sscdn.co/letras/250x250/fotos/a...     #C4557F
# 3    https://akamai.sscdn.co/letras/250x250/fotos/9...     #4240B1
# 4    https://akamai.sscdn.co/letras/250x250/fotos/4...     #AAA833
# ..                                                 ...         ...
# 995  https://akamai.sscdn.co/letras/250x250/fotos/9...     #E8A925
# 996  https://akamai.sscdn.co/letras/250x250/fotos/1...     #C43A3A
# 997  https://akamai.sscdn.co/letras/250x250/fotos/5...     #BA52C7
# 998  https://akamai.sscdn.co/letras/250x250/fotos/0...     #60372A
# 999  https://akamai.sscdn.co/letras/250x250/fotos/7...     #E8A925
#
#      inappropriateContent.artist  inappropriateContent.albuns  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                         True
# 3                          False                        False
# 4                          False                        False
# ..                           ...                          ...
# 995                        False                        False
# 996                        False                        False
# 997                        False                        False
# 998                        False                        False
# 999                        False                        False
#
#      inappropriateContent.photos  genre
# 0                          False    NaN
# 1                          False    NaN
# 2                          False    NaN
# 3                          False    NaN
# 4                          False    NaN
# ..                           ...    ...
# 995                        False    NaN
# 996                        False    NaN
# 997                        False    NaN
# 998                        False    NaN
# 999                        False    NaN
#
# [1000 rows x 17 columns]

# %%
df_artist["pandas_id"] = df_artist.index
df_artist.set_index("pandas_id", inplace=True)
df_artist.drop(columns=[
    "id", \
    "image.50", \
    "image.250", \
    "image.162", \
    "headImage", \
    "genre.id", \
    "songs", \
    "totalPhotos",\
    "inappropriateContent.artist",\
    "inappropriateContent.photos", \
    "inappropriateContent.albuns", \
    "image.color", \
    "genre", \
], inplace=True)
df_artist
# Out:
#                            name                   url        genre.name  \
# pandas_id
# 0                  Maria Marçal          maria-marcal  Gospel/Religioso
# 1                    Theo Rubia            theo-rubia  Gospel/Religioso
# 2            Henrique e Juliano    henrique-e-juliano         Sertanejo
# 3          Chitãozinho & Xororó  chitaozinho-e-xororo         Sertanejo
# 4           Jefferson & Suellen   jefferson-e-suellen  Gospel/Religioso
# ...                         ...                   ...               ...
# 995                  Armandinho            armandinho            Reggae
# 996         Di Paullo e Paulino    di-paulo-e-paulino         Sertanejo
# 997            Hugo e Guilherme        hugo-guilherme         Sertanejo
# 998                Heloísa Rosa          heloisa-rosa  Gospel/Religioso
# 999                  Kid Abelha            kid-abelha          Pop Rock
#
#                  genre.url
# pandas_id
# 0          gospelreligioso
# 1          gospelreligioso
# 2                sertanejo
# 3                sertanejo
# 4          gospelreligioso
# ...                    ...
# 995                 reggae
# 996              sertanejo
# 997              sertanejo
# 998        gospelreligioso
# 999                poprock
#
# [1000 rows x 4 columns]

# %%
df_songs.drop(columns=["artist", "id", "hits"], inplace=True) 

df = pd.merge(df_songs, df_artist, on="pandas_id", suffixes=('_song', '_artist'))
df
# Out:
#                                                    name_song  \
# pandas_id
# 0                                                    Deserto
# 1                                            Pode Morar Aqui
# 2                                            A Maior Saudade
# 3                                                 Evidências
# 4                                              Vem Me Buscar
# ...                                                      ...
# 995                                   Outra Noite Que Se Vai
# 996                                               Estrelinha
# 997        Te Amar Foi Ilusão / Passou da Conta / Convite...
# 998                                   Quero Ser Como Criança
# 999                                         Lágrimas e Chuva
#
#                                                     url_song         mod  \
# pandas_id
# 0                                                    deserto    revisada
# 1                                            pode-morar-aqui  video-aula
# 2                                            a-maior-saudade  video-aula
# 3                                                 evidencias  video-aula
# 4                                              vem-me-buscar  video-aula
# ...                                                      ...         ...
# 995                                   outra-noite-que-se-vai    revisada
# 996                                               estrelinha
# 997        te-amar-foi-ilusao-passou-da-conta-convite-de-...
# 998                                   quero-ser-como-crianca    revisada
# 999                                           lagrimas-chuva  video-aula
#
#                     name_artist            url_artist        genre.name  \
# pandas_id
# 0                  Maria Marçal          maria-marcal  Gospel/Religioso
# 1                    Theo Rubia            theo-rubia  Gospel/Religioso
# 2            Henrique e Juliano    henrique-e-juliano         Sertanejo
# 3          Chitãozinho & Xororó  chitaozinho-e-xororo         Sertanejo
# 4           Jefferson & Suellen   jefferson-e-suellen  Gospel/Religioso
# ...                         ...                   ...               ...
# 995                  Armandinho            armandinho            Reggae
# 996         Di Paullo e Paulino    di-paulo-e-paulino         Sertanejo
# 997            Hugo e Guilherme        hugo-guilherme         Sertanejo
# 998                Heloísa Rosa          heloisa-rosa  Gospel/Religioso
# 999                  Kid Abelha            kid-abelha          Pop Rock
#
#                  genre.url
# pandas_id
# 0          gospelreligioso
# 1          gospelreligioso
# 2                sertanejo
# 3                sertanejo
# 4          gospelreligioso
# ...                    ...
# 995                 reggae
# 996              sertanejo
# 997              sertanejo
# 998        gospelreligioso
# 999                poprock
#
# [1000 rows x 7 columns]

# %% [markdown]
# # APPLY WEB SCRAPER

# %%
from bs4 import BeautifulSoup

# %%
def get_url(artist_url, song_name_url):
    song_url = "https://m.cifraclub.com.br/%s/%s/#instrument=guitar" % (artist_url, song_name_url)
    return song_url

# %%
def get_chords(artist_url, song_name_url):
    r = requests.get(get_url("henrique-e-juliano", "cidade-vizinha"))
    c = r.content
    soup = BeautifulSoup(c, "html.parser")
    chords = soup.find_all("div", {"class":"chordWrapper"})

    chords_list = ""

    for i in range(len(chords)):
        chords_str += chords[i].find("strong").text
        chords_str += ";"

    return chords_str

# %%
df["chords"] = df.apply(lambda dr: get_chords(dr.url_artist, dr.url_song), axis=1)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 df["chords"] = df.apply(lambda dr: get_chords(dr.url_artist, dr.url_song), axis=1)
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py:9555, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9544 from pandas.core.apply import frame_apply
#    9546 op = frame_apply(
#    9547     self,
#    9548     func=func,
#    (...)
#    9553     kwargs=kwargs,
#    9554 )
# -> 9555 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\apply.py:746, in FrameApply.apply(self)
#     743 elif self.raw:
#     744     return self.apply_raw()
# --> 746 return self.apply_standard()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\apply.py:873, in FrameApply.apply_standard(self)
#     872 def apply_standard(self):
# --> 873     results, res_index = self.apply_series_generator()
#     875     # wrap results
#     876     return self.wrap_results(results, res_index)
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\apply.py:889, in FrameApply.apply_series_generator(self)
#     886 with option_context("mode.chained_assignment", None):
#     887     for i, v in enumerate(series_gen):
#     888         # ignore SettingWithCopy here in case the user mutates
# --> 889         results[i] = self.f(v)
#     890         if isinstance(results[i], ABCSeries):
#     891             # If we have a view on v, we need to make a copy because
#     892             #  series_generator will swap out the underlying data
#     893             results[i] = results[i].copy(deep=False)
#
# Cell In [12], line 1, in <lambda>(dr)
# ----> 1 df["chords"] = df.apply(lambda dr: get_chords(dr.url_artist, dr.url_song), axis=1)
#
# Cell In [11], line 10, in get_chords(artist_url, song_name_url)
#       7 chords_list = ""
#       9 for i in range(len(chords)):
# ---> 10     chords_str += chords[i].find("strong").text
#      11     chords_str += ";"
#      13 return chords_str
#
# UnboundLocalError: local variable 'chords_str' referenced before assignment

# %% [markdown]
# # DATA

# %%
#STRING TO LIST

df.drop(columns=["genre.url", "url_artist", "url_song"], inplace=True)

df.rename(columns={"name_song": "song", "name_artist": "artist", "genre.name": "genre"}, inplace=True)

df
# Out:
#                                                         song         mod  \
# pandas_id
# 0                                                    Deserto    revisada
# 1                                            Pode Morar Aqui  video-aula
# 2                                            A Maior Saudade  video-aula
# 3                                                 Evidências  video-aula
# 4                                              Vem Me Buscar  video-aula
# ...                                                      ...         ...
# 995                                   Outra Noite Que Se Vai    revisada
# 996                                               Estrelinha
# 997        Te Amar Foi Ilusão / Passou da Conta / Convite...
# 998                                   Quero Ser Como Criança    revisada
# 999                                         Lágrimas e Chuva  video-aula
#
#                          artist             genre
# pandas_id
# 0                  Maria Marçal  Gospel/Religioso
# 1                    Theo Rubia  Gospel/Religioso
# 2            Henrique e Juliano         Sertanejo
# 3          Chitãozinho & Xororó         Sertanejo
# 4           Jefferson & Suellen  Gospel/Religioso
# ...                         ...               ...
# 995                  Armandinho            Reggae
# 996         Di Paullo e Paulino         Sertanejo
# 997            Hugo e Guilherme         Sertanejo
# 998                Heloísa Rosa  Gospel/Religioso
# 999                  Kid Abelha          Pop Rock
#
# [1000 rows x 4 columns]

# %%
print(df["mod"].unique())
# Out:
# ['revisada' 'video-aula' '']

# %%
import quandl
import pymongo
from pymongo import MongoClient

# %%
# Making a Connection with MongoClient

client = MongoClient("mongodb+srv://rusbe:rusbezim@cinfra-club.csmendp.mongodb.net/?retryWrites=true&w=majority")

# database
db = client["chords"]
# collection
collection= db["Colle"]

# df.reset_index(inplace=True)
data_dict = df.to_dict("records")
#Insert collection in database
collection.insert_one({"index":"song","data":data_dict})
