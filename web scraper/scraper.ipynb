# %%
import requests
import pandas as pd
import json

# %% [markdown]
# # GET SONGS

# %%
url = "https://api.cifraclub.com.br/v3/tops?genre=all&" +\
  "instrument=guitar&" +\
  "period=semana&" +\
  "limitSongs=1000&" +\
  "limitArtists=0" +\
  "&offsetSongs=0&" +\
  "offsetArtists=0"

payload={}
headers = {
  'Accept': '*/*',
  'Accept-Language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,ja-JP;q=0.6,ja;q=0.5',
  'Connection': 'keep-alive',
  'Origin': 'https://www.cifraclub.com.br',
  'Referer': 'https://www.cifraclub.com.br/',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-site',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36',
  'X-Authorization': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..KYuZCi4m_vabxOjgo9R3xF7FxagBQZuKNp9jcxAh5Z3U61KxrhaJb9AeQ9TNYfW0C8WzkK3x0Vj3efIVhCqRCXdDRF9QTNChrt7SOApUxvJmwD9oO5BVx2DK_0M1-xJ3yrgrDIPq_3cjPeVT9erwYo70V9h35UGXue8xE_m2YLiOWH5w8XCd6ZfpHkeScu-OrreX3RgXQamXSLaXdY-alTEogCJVhHkO0qNcvStzdFoAvwLuNfbB3_pkIki3aShjhQ_E6f6kfUxoqhkYZNY8b394IaSrZ5P0S9u81X1LoMA_xSY-PARa5fYnMsNmEWEi57WL9bSrCaG9RkuUJ3dz6w',
  'sec-ch-ua': '"Chromium";v="106", "Google Chrome";v="106", "Not;A=Brand";v="99"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

response = requests.request("GET", url, headers=headers, data=payload)

# %%
json_res = response.json()

# %%
df_songs = pd.DataFrame(json_res["songs"])
df_songs
# Out:
#          id                                               name  \
# 0    738834                                            Deserto
# 1    475833                                    Pode Morar Aqui
# 2    716152                                    A Maior Saudade
# 3      1906                                         Evidências
# 4    724683                                      Vem Me Buscar
# ..      ...                                                ...
# 995  401533                                      Seja Para Mim
# 996  297801                                   Amigo Estou Aqui
# 997     638                                       O Passageiro
# 998  737641  Um Sonhador / Não Precisa / Não Aprendi a Dize...
# 999    4178                                 Amor Pra Recomeçar
#
#                                                    url  \
# 0                                              deserto
# 1                                      pode-morar-aqui
# 2                                      a-maior-saudade
# 3                                           evidencias
# 4                                        vem-me-buscar
# ..                                                 ...
# 995                                      seja-para-mim
# 996                                   amigo-estou-aqui
# 997                                       o-passageiro
# 998  um-sonhador-nao-precisa-nao-aprendi-a-dizer-adeus
# 999                                 amor-pra-recomecar
#
#                                                 artist    hits         mod
# 0    {'id': 321205, 'name': 'Maria Marçal', 'url': ...  121525    revisada
# 1    {'id': 156142, 'name': 'Theo Rubia', 'url': 't...   84528  video-aula
# 2    {'id': 127408, 'name': 'Henrique e Juliano', '...   63237  video-aula
# 3    {'id': 6956, 'name': 'Chitãozinho & Xororó', '...   59792  video-aula
# 4    {'id': 263513, 'name': 'Jefferson & Suellen', ...   54784  video-aula
# ..                                                 ...     ...         ...
# 995  {'id': 47032, 'name': 'Maneva', 'url': 'maneva...    2676    revisada
# 996  {'id': 31630, 'name': 'Toy Story', 'url': 'toy...    2674  video-aula
# 997  {'id': 824, 'name': 'Capital Inicial', 'url': ...    2671  video-aula
# 998  {'id': 205265, 'name': 'Lauana Prado', 'url': ...    2669    revisada
# 999  {'id': 7058, 'name': 'Frejat', 'url': 'frejat'...    2668  video-aula
#
# [1000 rows x 6 columns]

# %%
df_songs["pandas_id"] = df_songs.index
df_songs.set_index("pandas_id", inplace=True)
df_songs
# Out:
#                id                                               name  \
# pandas_id
# 0          738834                                            Deserto
# 1          475833                                    Pode Morar Aqui
# 2          716152                                    A Maior Saudade
# 3            1906                                         Evidências
# 4          724683                                      Vem Me Buscar
# ...           ...                                                ...
# 995        401533                                      Seja Para Mim
# 996        297801                                   Amigo Estou Aqui
# 997           638                                       O Passageiro
# 998        737641  Um Sonhador / Não Precisa / Não Aprendi a Dize...
# 999          4178                                 Amor Pra Recomeçar
#
#                                                          url  \
# pandas_id
# 0                                                    deserto
# 1                                            pode-morar-aqui
# 2                                            a-maior-saudade
# 3                                                 evidencias
# 4                                              vem-me-buscar
# ...                                                      ...
# 995                                            seja-para-mim
# 996                                         amigo-estou-aqui
# 997                                             o-passageiro
# 998        um-sonhador-nao-precisa-nao-aprendi-a-dizer-adeus
# 999                                       amor-pra-recomecar
#
#                                                       artist    hits  \
# pandas_id
# 0          {'id': 321205, 'name': 'Maria Marçal', 'url': ...  121525
# 1          {'id': 156142, 'name': 'Theo Rubia', 'url': 't...   84528
# 2          {'id': 127408, 'name': 'Henrique e Juliano', '...   63237
# 3          {'id': 6956, 'name': 'Chitãozinho & Xororó', '...   59792
# 4          {'id': 263513, 'name': 'Jefferson & Suellen', ...   54784
# ...                                                      ...     ...
# 995        {'id': 47032, 'name': 'Maneva', 'url': 'maneva...    2676
# 996        {'id': 31630, 'name': 'Toy Story', 'url': 'toy...    2674
# 997        {'id': 824, 'name': 'Capital Inicial', 'url': ...    2671
# 998        {'id': 205265, 'name': 'Lauana Prado', 'url': ...    2669
# 999        {'id': 7058, 'name': 'Frejat', 'url': 'frejat'...    2668
#
#                   mod
# pandas_id
# 0            revisada
# 1          video-aula
# 2          video-aula
# 3          video-aula
# 4          video-aula
# ...               ...
# 995          revisada
# 996        video-aula
# 997        video-aula
# 998          revisada
# 999        video-aula
#
# [1000 rows x 6 columns]

# %%
df_artist = pd.json_normalize(df_songs.artist)
df_artist
# Out:
#          id                  name                   url  totalPhotos  \
# 0    321205          Maria Marçal          maria-marcal            1
# 1    156142            Theo Rubia            theo-rubia            4
# 2    127408    Henrique e Juliano    henrique-e-juliano           51
# 3      6956  Chitãozinho & Xororó  chitaozinho-e-xororo          123
# 4    263513   Jefferson & Suellen   jefferson-e-suellen            4
# ..      ...                   ...                   ...          ...
# 995   47032                Maneva                maneva            3
# 996   31630             Toy Story             toy-story            2
# 997     824       Capital Inicial       capital-inicial           34
# 998  205265          Lauana Prado          lauana-prado           21
# 999    7058                Frejat                frejat           15
#
#     headImage songs  genre.id        genre.name        genre.url  \
# 0        None  None      30.0  Gospel/Religioso  gospelreligioso
# 1        None  None      30.0  Gospel/Religioso  gospelreligioso
# 2        None  None       9.0         Sertanejo        sertanejo
# %%
df_artist["pandas_id"] = df_artist.index
df_artist.set_index("pandas_id", inplace=True)
df_artist.drop(columns=[
    "id", \
    "image.50", \
    "image.250", \
    "image.162", \
    "headImage", \
    "genre.id", \
    "songs", \
    "totalPhotos",\
    "inappropriateContent.artist",\
    "inappropriateContent.photos", \
    "inappropriateContent.albuns", \
    "image.color", \
    "genre", \
], inplace=True)
df_artist
# Out:
#                            name                   url        genre.name  \
# pandas_id
# 0                  Maria Marçal          maria-marcal  Gospel/Religioso
# 1                    Theo Rubia            theo-rubia  Gospel/Religioso
# 2            Henrique e Juliano    henrique-e-juliano         Sertanejo
# 3          Chitãozinho & Xororó  chitaozinho-e-xororo         Sertanejo
# 4           Jefferson & Suellen   jefferson-e-suellen  Gospel/Religioso
# ...                         ...                   ...               ...
# 995                      Maneva                maneva            Reggae
# 996                   Toy Story             toy-story          Infantil
# 997             Capital Inicial       capital-inicial     Rock and Roll
# 998                Lauana Prado          lauana-prado         Sertanejo
# 999                      Frejat                frejat          Pop Rock
#
#                  genre.url
# pandas_id
# 0          gospelreligioso
# 1          gospelreligioso
# 2                sertanejo
# 3                sertanejo
# 4          gospelreligioso
# ...                    ...
# 995                 reggae
# 996               infantil
# 997              rock-roll
# 998              sertanejo
# 999                poprock
#
# [1000 rows x 4 columns]

# %%
df_songs.drop(columns=["artist", "id", "hits"], inplace=True) 

df = pd.merge(df_songs, df_artist, on="pandas_id", suffixes=('_song', '_artist'))
df
# Out:
#                                                    name_song  \
# pandas_id
# 0                                                    Deserto
# 1                                            Pode Morar Aqui
# 2                                            A Maior Saudade
# 3                                                 Evidências
# 4                                              Vem Me Buscar
# ...                                                      ...
# 995                                            Seja Para Mim
# 996                                         Amigo Estou Aqui
# 997                                             O Passageiro
# 998        Um Sonhador / Não Precisa / Não Aprendi a Dize...
# 999                                       Amor Pra Recomeçar
#
#                                                     url_song         mod  \
# pandas_id
# 0                                                    deserto    revisada
# 1                                            pode-morar-aqui  video-aula
# 2                                            a-maior-saudade  video-aula
# 3                                                 evidencias  video-aula
# 4                                              vem-me-buscar  video-aula
# ...                                                      ...         ...
# 995                                            seja-para-mim    revisada
# 996                                         amigo-estou-aqui  video-aula
# 997                                             o-passageiro  video-aula
# 998        um-sonhador-nao-precisa-nao-aprendi-a-dizer-adeus    revisada
# 999                                       amor-pra-recomecar  video-aula
#
#                     name_artist            url_artist        genre.name  \
# pandas_id
# 0                  Maria Marçal          maria-marcal  Gospel/Religioso
# 1                    Theo Rubia            theo-rubia  Gospel/Religioso
# 2            Henrique e Juliano    henrique-e-juliano         Sertanejo
# 3          Chitãozinho & Xororó  chitaozinho-e-xororo         Sertanejo
# 4           Jefferson & Suellen   jefferson-e-suellen  Gospel/Religioso
# ...                         ...                   ...               ...
# 995                      Maneva                maneva            Reggae
# 996                   Toy Story             toy-story          Infantil
# 997             Capital Inicial       capital-inicial     Rock and Roll
# 998                Lauana Prado          lauana-prado         Sertanejo
# 999                      Frejat                frejat          Pop Rock
#
#                  genre.url
# pandas_id
# 0          gospelreligioso
# 1          gospelreligioso
# 2                sertanejo
# 3                sertanejo
# 4          gospelreligioso
# ...                    ...
# 995                 reggae
# 996               infantil
# 997              rock-roll
# 998              sertanejo
# 999                poprock
#
# [1000 rows x 7 columns]

# %% [markdown]
# # APPLY WEB SCRAPER

# %%
from bs4 import BeautifulSoup

# %%
def get_url(artist_url, song_name_url):
    song_url = "https://m.cifraclub.com.br/%s/%s/#instrument=guitar" % (artist_url, song_name_url)
    return song_url

# %%
def get_chords(artist_url, song_name_url):
    chords_str = ""
    r = requests.get(get_url("henrique-e-juliano", "cidade-vizinha"))
    c = r.content
    soup = BeautifulSoup(c, "html.parser")
    chords = soup.find_all("div", {"class":"chordWrapper"})

    chords_list = ""

    for i in range(len(chords)):
        chords_str += chords[i].find("strong").text
        chords_str += ";"

    return chords_str

# %%
df["chords"] = df.apply(lambda dr: get_chords(dr.url_artist, dr.url_song), axis=1)

# %% [markdown]
# # DATA

# %%
#STRING TO LIST

df.drop(columns=["genre.url", "url_artist", "url_song"], inplace=True)

df.rename(columns={"name_song": "song", "name_artist": "artist", "genre.name": "genre"}, inplace=True)

df
# Out:
#                                                         song         mod  \
# pandas_id
# 0                                                    Deserto    revisada
# 1                                            Pode Morar Aqui  video-aula
# 2                                            A Maior Saudade  video-aula
# 3                                                 Evidências  video-aula
# 4                                              Vem Me Buscar  video-aula
# ...                                                      ...         ...
# 995                                            Seja Para Mim    revisada
# 996                                         Amigo Estou Aqui  video-aula
# 997                                             O Passageiro  video-aula
# 998        Um Sonhador / Não Precisa / Não Aprendi a Dize...    revisada
# 999                                       Amor Pra Recomeçar  video-aula
#
#                          artist             genre  \
# pandas_id
# 0                  Maria Marçal  Gospel/Religioso
# 1                    Theo Rubia  Gospel/Religioso
# 2            Henrique e Juliano         Sertanejo
# 3          Chitãozinho & Xororó         Sertanejo
# 4           Jefferson & Suellen  Gospel/Religioso
# ...                         ...               ...
# 995                      Maneva            Reggae
# 996                   Toy Story          Infantil
# 997             Capital Inicial     Rock and Roll
# 998                Lauana Prado         Sertanejo
# 999                      Frejat          Pop Rock
#
#                                                    chords
# pandas_id
# 0          Bm7(11)*;C9*;D*;D4*;D9*;Em7*;G*;G11+*;G5*;G6*;
# 1          Bm7(11)*;C9*;D*;D4*;D9*;Em7*;G*;G11+*;G5*;G6*;
# 2          Bm7(11)*;C9*;D*;D4*;D9*;Em7*;G*;G11+*;G5*;G6*;
# 3          Bm7(11)*;C9*;D*;D4*;D9*;Em7*;G*;G11+*;G5*;G6*;
# 4          Bm7(11)*;C9*;D*;D4*;D9*;Em7*;G*;G11+*;G5*;G6*;
# ...                                                   ...
# 995        Bm7(11)*;C9*;D*;D4*;D9*;Em7*;G*;G11+*;G5*;G6*;
# 996        Bm7(11)*;C9*;D*;D4*;D9*;Em7*;G*;G11+*;G5*;G6*;
# 997        Bm7(11)*;C9*;D*;D4*;D9*;Em7*;G*;G11+*;G5*;G6*;
# 998        Bm7(11)*;C9*;D*;D4*;D9*;Em7*;G*;G11+*;G5*;G6*;
# 999        Bm7(11)*;C9*;D*;D4*;D9*;Em7*;G*;G11+*;G5*;G6*;
#
# [1000 rows x 5 columns]

# %%
print(df["mod"].unique())
# Out:
# ['revisada' 'video-aula' '']

# %%
def encodeMod (mod):
    if mod == 'video aula':
        return 0
    elif mod == 'revisada':
        return 1
    else:
         return 2


df['mod'] = df['mod'].map(encodeMod)

# %%
import quandl
import pymongo
from pymongo import MongoClient

# %%
df.reset_index(inplace=True)

# %%
# Making a Connection with MongoClient

client = MongoClient("mongodb+srv://rusbe:rusbezim@cinfra-club.csmendp.mongodb.net/?retryWrites=true&w=majority")

# database
db = client["chords"]
# collection
collection= db["songs"]

data_dict = df.to_dict("records")
#Insert collection in database
collection.insert_one({"data":data_dict})
