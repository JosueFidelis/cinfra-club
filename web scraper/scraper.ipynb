# %%
import requests
import pandas as pd
import json

# %% [markdown]
# # GET SONGS

# %%
genres = ["alternativo", "axe", "blues", "bolero", "bossa-nova", "brega", "classico", "country", "cuarteto", "cumbia", "dance", "disco", "eletronica", "emocore", "fado", "folk", "forro", "funk", "funk-internacional", "gospelreligioso", "grunge", "guarania", "hard-rock", "hardcore", "heavy-metal", "house", "indie", "industrial", "infantil", "instrumental", "jazz", "jovem-guarda", "k-pop", "mpb", "mambo", "mariachi", "merengue", "musica-andina", "new-age", "new-wave", "pagode", "pop", "pop-rock", "post-rock", "power-rock", "psicodelia", "punk-rock", "ranchera", "reggae", "reggaeton", "regional", "rock", "rock-progressivo", "rockabilly", "romantico", "salsa", "samba", "samba-enredo", "sertanejo", "ska", "soft-rock", "soul", "surf-music", "tango", "tecnopop", "trova", "velha-guarda", "world-music", "zamba", "zouk"]

# %%
url = "https://api.cifraclub.com.br/v3/tops?genre=all&" +\
  "instrument=guitar&" +\
  "period=semana&" +\
  "limitSongs=1000&" +\
  "limitArtists=0" +\
  "&offsetSongs=0&" +\
  "offsetArtists=0"

payload={}
headers = {
  'Accept': '*/*',
  'Accept-Language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,ja-JP;q=0.6,ja;q=0.5',
  'Connection': 'keep-alive',
  'Origin': 'https://www.cifraclub.com.br',
  'Referer': 'https://www.cifraclub.com.br/',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-site',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36',
  'X-Authorization': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..KYuZCi4m_vabxOjgo9R3xF7FxagBQZuKNp9jcxAh5Z3U61KxrhaJb9AeQ9TNYfW0C8WzkK3x0Vj3efIVhCqRCXdDRF9QTNChrt7SOApUxvJmwD9oO5BVx2DK_0M1-xJ3yrgrDIPq_3cjPeVT9erwYo70V9h35UGXue8xE_m2YLiOWH5w8XCd6ZfpHkeScu-OrreX3RgXQamXSLaXdY-alTEogCJVhHkO0qNcvStzdFoAvwLuNfbB3_pkIki3aShjhQ_E6f6kfUxoqhkYZNY8b394IaSrZ5P0S9u81X1LoMA_xSY-PARa5fYnMsNmEWEi57WL9bSrCaG9RkuUJ3dz6w',
  'sec-ch-ua': '"Chromium";v="106", "Google Chrome";v="106", "Not;A=Brand";v="99"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

response = requests.request("GET", url, headers=headers, data=payload)

# %%
json_res = response.json()

# %%
df_songs = pd.DataFrame(json_res["songs"])
df_songs
# Out:
#          id                                      name  \
# 0    738834                                   Deserto
# 1    475833                           Pode Morar Aqui
# 2    716152                           A Maior Saudade
# 3      1906                                Evidências
# 4    724683                             Vem Me Buscar
# ..      ...                                       ...
# 995  288729                          Cordeiro de Deus
# 996    2395                              Ovelha Negra
# 997    2946                                 Relicário
# 998    4340                                    Sparks
# 999  718407  Cê Tá Preparada (part. Marília Mendonça)
#
#                                        url  \
# 0                                  deserto
# 1                          pode-morar-aqui
# 2                          a-maior-saudade
# 3                               evidencias
# 4                            vem-me-buscar
# ..                                     ...
# 995                       cordeiro-de-deus
# 996                           ovelha-negra
# 997                              relicario
# 998                                 sparks
# 999  ce-ta-preparada-part-marilia-mendonca
#
#                                                 artist    hits         mod
# 0    {'id': 321205, 'name': 'Maria Marçal', 'url': ...  119804    revisada
# 1    {'id': 156142, 'name': 'Theo Rubia', 'url': 't...   83442  video-aula
# 2    {'id': 127408, 'name': 'Henrique e Juliano', '...   63003  video-aula
# 3    {'id': 6956, 'name': 'Chitãozinho & Xororó', '...   60006  video-aula
# 4    {'id': 263513, 'name': 'Jefferson & Suellen', ...   54918  video-aula
# ..                                                 ...     ...         ...
# 995  {'id': 34474, 'name': 'Comunidade Católica Sha...    2674
# 996  {'id': 60, 'name': 'Rita Lee', 'url': 'rita-le...    2674  video-aula
# 997  {'id': 7237, 'name': 'Nando Reis', 'url': 'nan...    2669  video-aula
# 998  {'id': 1033, 'name': 'Coldplay', 'url': 'coldp...    2669
# 999  {'id': 227244, 'name': 'Tayrone', 'url': 'tayr...    2668    revisada
#
# [1000 rows x 6 columns]

# %%
df_songs["pandas_id"] = df_songs.index
df_songs.set_index("pandas_id", inplace=True)
df_songs
# Out:
#                id                                      name  \
# pandas_id
# 0          738834                                   Deserto
# 1          475833                           Pode Morar Aqui
# 2          716152                           A Maior Saudade
# 3            1906                                Evidências
# 4          724683                             Vem Me Buscar
# ...           ...                                       ...
# 995        288729                          Cordeiro de Deus
# 996          2395                              Ovelha Negra
# 997          2946                                 Relicário
# 998          4340                                    Sparks
# 999        718407  Cê Tá Preparada (part. Marília Mendonça)
#
#                                              url  \
# pandas_id
# 0                                        deserto
# 1                                pode-morar-aqui
# 2                                a-maior-saudade
# 3                                     evidencias
# 4                                  vem-me-buscar
# ...                                          ...
# 995                             cordeiro-de-deus
# 996                                 ovelha-negra
# 997                                    relicario
# 998                                       sparks
# 999        ce-ta-preparada-part-marilia-mendonca
#
#                                                       artist    hits  \
# pandas_id
# 0          {'id': 321205, 'name': 'Maria Marçal', 'url': ...  119804
# 1          {'id': 156142, 'name': 'Theo Rubia', 'url': 't...   83442
# 2          {'id': 127408, 'name': 'Henrique e Juliano', '...   63003
# 3          {'id': 6956, 'name': 'Chitãozinho & Xororó', '...   60006
# 4          {'id': 263513, 'name': 'Jefferson & Suellen', ...   54918
# ...                                                      ...     ...
# 995        {'id': 34474, 'name': 'Comunidade Católica Sha...    2674
# 996        {'id': 60, 'name': 'Rita Lee', 'url': 'rita-le...    2674
# 997        {'id': 7237, 'name': 'Nando Reis', 'url': 'nan...    2669
# 998        {'id': 1033, 'name': 'Coldplay', 'url': 'coldp...    2669
# 999        {'id': 227244, 'name': 'Tayrone', 'url': 'tayr...    2668
#
#                   mod
# pandas_id
# 0            revisada
# 1          video-aula
# 2          video-aula
# 3          video-aula
# 4          video-aula
# ...               ...
# 995
# 996        video-aula
# 997        video-aula
# 998
# 999          revisada
#
# [1000 rows x 6 columns]

# %%
df_artist = pd.json_normalize(df_songs.artist)
df_artist
# Out:
#          id                        name                         url  \
# 0    321205                Maria Marçal                maria-marcal
# 1    156142                  Theo Rubia                  theo-rubia
# 2    127408          Henrique e Juliano          henrique-e-juliano
# 3      6956        Chitãozinho & Xororó        chitaozinho-e-xororo
# 4    263513         Jefferson & Suellen         jefferson-e-suellen
# ..      ...                         ...                         ...
# 995   34474  Comunidade Católica Shalom  comunidade-catolica-shalom
# 996      60                    Rita Lee                    rita-lee
# 997    7237                  Nando Reis                  nando-reis
# 998    1033                    Coldplay                    coldplay
# 999  227244                     Tayrone                     tayrone
#
#      totalPhotos headImage songs  genre.id        genre.name        genre.url  \
# 0              1      None  None      30.0  Gospel/Religioso  gospelreligioso
# 1              4      None  None      30.0  Gospel/Religioso  gospelreligioso
# 2             51      None  None       9.0         Sertanejo        sertanejo
# 3            123      None  None       9.0         Sertanejo        sertanejo
# 4              4      None  None      30.0  Gospel/Religioso  gospelreligioso
# ..           ...       ...   ...       ...               ...              ...
# 995            1      None  None      30.0  Gospel/Religioso  gospelreligioso
# 996           47      None  None       3.0     Rock and Roll        rock-roll
# 997           35      None  None       5.0               MPB              mpb
# 998           81      None  None       2.0          Pop Rock          poprock
# 999            1      None  None       NaN               NaN              NaN
#
#                                               image.50  \
# 0    https://akamai.sscdn.co/letras/50x50/fotos/5/6...
# 1    https://akamai.sscdn.co/letras/50x50/fotos/7/a...
# 2    https://akamai.sscdn.co/letras/50x50/fotos/a/f...
# 3    https://akamai.sscdn.co/letras/50x50/fotos/2/2...
# 4    https://akamai.sscdn.co/letras/50x50/fotos/4/7...
# ..                                                 ...
# 995  https://akamai.sscdn.co/letras/50x50/fotos/4/4...
# 996  https://akamai.sscdn.co/letras/50x50/fotos/f/5...
# 997  https://akamai.sscdn.co/letras/50x50/fotos/3/f...
# 998  https://akamai.sscdn.co/letras/50x50/fotos/b/b...
# 999  https://akamai.sscdn.co/letras/50x50/fotos/8/8...
#
#                                              image.162  \
# 0    https://akamai.sscdn.co/letras/162x162/fotos/5...
# 1    https://akamai.sscdn.co/letras/162x162/fotos/7...
# 2    https://akamai.sscdn.co/letras/162x162/fotos/a...
# 3    https://akamai.sscdn.co/letras/162x162/fotos/2...
# 4    https://akamai.sscdn.co/letras/162x162/fotos/4...
# ..                                                 ...
# 995  https://akamai.sscdn.co/letras/162x162/fotos/4...
# 996  https://akamai.sscdn.co/letras/162x162/fotos/f...
# 997  https://akamai.sscdn.co/letras/162x162/fotos/3...
# 998  https://akamai.sscdn.co/letras/162x162/fotos/b...
# 999  https://akamai.sscdn.co/letras/162x162/fotos/8...
#
#                                              image.250 image.color  \
# 0    https://akamai.sscdn.co/letras/250x250/fotos/5...     #387ED6
# 1    https://akamai.sscdn.co/letras/250x250/fotos/7...     #D76432
# 2    https://akamai.sscdn.co/letras/250x250/fotos/a...     #C4557F
# 3    https://akamai.sscdn.co/letras/250x250/fotos/2...     #7FAA33
# 4    https://akamai.sscdn.co/letras/250x250/fotos/4...     #AAA833
# ..                                                 ...         ...
# 995  https://akamai.sscdn.co/letras/250x250/fotos/4...     #E15849
# 996  https://akamai.sscdn.co/letras/250x250/fotos/f...     #DF7734
# 997  https://akamai.sscdn.co/letras/250x250/fotos/3...     #D76432
# 998  https://akamai.sscdn.co/letras/250x250/fotos/b...     #3DA4B4
# 999  https://akamai.sscdn.co/letras/250x250/fotos/8...     #387ED6
#
#      inappropriateContent.artist  inappropriateContent.albuns  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                         True
# 3                          False                        False
# 4                          False                        False
# ..                           ...                          ...
# 995                        False                        False
# 996                        False                        False
# 997                        False                        False
# 998                        False                        False
# 999                        False                        False
#
#      inappropriateContent.photos  genre
# 0                          False    NaN
# 1                          False    NaN
# 2                          False    NaN
# 3                          False    NaN
# 4                          False    NaN
# ..                           ...    ...
# 995                        False    NaN
# 996                        False    NaN
# 997                        False    NaN
# 998                        False    NaN
# 999                        False    NaN
#
# [1000 rows x 17 columns]

# %%
df_artist["pandas_id"] = df_artist.index
df_artist.set_index("pandas_id", inplace=True)
df_artist.drop(columns=[
    "id", \
    "image.50", \
    "image.250", \
    "image.162", \
    "headImage", \
    "genre.id", \
    "songs", \
    "totalPhotos",\
    "inappropriateContent.artist",\
    "inappropriateContent.photos", \
    "inappropriateContent.albuns", \
    "image.color", \
    "genre", \
], inplace=True)
df_artist
# Out:
#                                  name                         url  \
# pandas_id
# 0                        Maria Marçal                maria-marcal
# 1                          Theo Rubia                  theo-rubia
# 2                  Henrique e Juliano          henrique-e-juliano
# 3                Chitãozinho & Xororó        chitaozinho-e-xororo
# 4                 Jefferson & Suellen         jefferson-e-suellen
# ...                               ...                         ...
# 995        Comunidade Católica Shalom  comunidade-catolica-shalom
# 996                          Rita Lee                    rita-lee
# 997                        Nando Reis                  nando-reis
# 998                          Coldplay                    coldplay
# 999                           Tayrone                     tayrone
#
#                  genre.name        genre.url
# pandas_id
# 0          Gospel/Religioso  gospelreligioso
# 1          Gospel/Religioso  gospelreligioso
# 2                 Sertanejo        sertanejo
# 3                 Sertanejo        sertanejo
# 4          Gospel/Religioso  gospelreligioso
# ...                     ...              ...
# 995        Gospel/Religioso  gospelreligioso
# 996           Rock and Roll        rock-roll
# 997                     MPB              mpb
# 998                Pop Rock          poprock
# 999                     NaN              NaN
#
# [1000 rows x 4 columns]

# %%
df_songs.drop(columns=["artist", "id", "hits"], inplace=True) 

df = pd.merge(df_songs, df_artist, on="pandas_id", suffixes=('_song', '_artist'))
df
# Out:
#                                           name_song  \
# pandas_id
# 0                                           Deserto
# 1                                   Pode Morar Aqui
# 2                                   A Maior Saudade
# 3                                        Evidências
# 4                                     Vem Me Buscar
# ...                                             ...
# 995                                Cordeiro de Deus
# 996                                    Ovelha Negra
# 997                                       Relicário
# 998                                          Sparks
# 999        Cê Tá Preparada (part. Marília Mendonça)
#
#                                         url_song         mod  \
# pandas_id
# 0                                        deserto    revisada
# 1                                pode-morar-aqui  video-aula
# 2                                a-maior-saudade  video-aula
# 3                                     evidencias  video-aula
# 4                                  vem-me-buscar  video-aula
# ...                                          ...         ...
# 995                             cordeiro-de-deus
# 996                                 ovelha-negra  video-aula
# 997                                    relicario  video-aula
# 998                                       sparks
# 999        ce-ta-preparada-part-marilia-mendonca    revisada
#
#                           name_artist                  url_artist  \
# pandas_id
# 0                        Maria Marçal                maria-marcal
# 1                          Theo Rubia                  theo-rubia
# 2                  Henrique e Juliano          henrique-e-juliano
# 3                Chitãozinho & Xororó        chitaozinho-e-xororo
# 4                 Jefferson & Suellen         jefferson-e-suellen
# ...                               ...                         ...
# 995        Comunidade Católica Shalom  comunidade-catolica-shalom
# 996                          Rita Lee                    rita-lee
# 997                        Nando Reis                  nando-reis
# 998                          Coldplay                    coldplay
# 999                           Tayrone                     tayrone
#
#                  genre.name        genre.url
# pandas_id
# 0          Gospel/Religioso  gospelreligioso
# 1          Gospel/Religioso  gospelreligioso
# 2                 Sertanejo        sertanejo
# 3                 Sertanejo        sertanejo
# 4          Gospel/Religioso  gospelreligioso
# ...                     ...              ...
# 995        Gospel/Religioso  gospelreligioso
# 996           Rock and Roll        rock-roll
# 997                     MPB              mpb
# 998                Pop Rock          poprock
# 999                     NaN              NaN
#
# [1000 rows x 7 columns]

# %% [markdown]
# # APPLY WEB SCRAPER

# %%
from bs4 import BeautifulSoup

# %%
def get_url(artist_url, song_name_url):
    song_url = "https://m.cifraclub.com.br/%s/%s/#instrument=guitar" % (artist_url, song_name_url)
    return song_url

# %%
def get_chords(artist_url, song_name_url):
    r = requests.get(get_url(artist_url, song_name_url))
    c = r.content
    soup = BeautifulSoup(c, "html.parser")
    chords = soup.find_all("div", {"class":"chordWrapper"})

    chords_list = []

    for i in range(len(chords)):
        chords_list.append(chords[i].find("strong").text)

    return chords_list

# %%
df["chords"] = df.apply(lambda dr: get_chords(dr.url_artist, dr.url_song), axis=1)

# %%
def encodeMod (mod):
    if mod == 'video aula':
        return 0
    elif mod == 'revisada':
        return 1
    else:
         return 2


df.drop(columns=["genre.url", "url_artist", "url_song"], inplace=True)

df.rename(columns={"name_song": "song", "name_artist": "artist", "genre.name": "genre"}, inplace=True)

df['mod'] = df['mod'].map(encodeMod)

df = df[df['chords'].map(lambda d: len(d)) > 0]

df
# Out:
#                                                song  mod  \
# pandas_id
# 0                                           Deserto    1
# 1                                   Pode Morar Aqui    2
# 2                                   A Maior Saudade    2
# 3                                        Evidências    2
# 4                                     Vem Me Buscar    2
# ...                                             ...  ...
# 995                                Cordeiro de Deus    2
# 996                                    Ovelha Negra    2
# 997                                       Relicário    2
# 998                                          Sparks    2
# 999        Cê Tá Preparada (part. Marília Mendonça)    1
#
#                                artist             genre  \
# pandas_id
# 0                        Maria Marçal  Gospel/Religioso
# 1                          Theo Rubia  Gospel/Religioso
# 2                  Henrique e Juliano         Sertanejo
# 3                Chitãozinho & Xororó         Sertanejo
# 4                 Jefferson & Suellen  Gospel/Religioso
# ...                               ...               ...
# 995        Comunidade Católica Shalom  Gospel/Religioso
# 996                          Rita Lee     Rock and Roll
# 997                        Nando Reis               MPB
# 998                          Coldplay          Pop Rock
# 999                           Tayrone               NaN
#
#                                                       chords
# pandas_id
# 0          [A, B, B/D#, C#m7, E, E9, F#, F#/A#, F#4, F#4(...
# 1                         [Am7*, C*, C/E*, Em*, F*, G*, G4*]
# 2                                [Am*, C*, Dm*, Em*, F*, G*]
# 3          [A, A/B, A/C#, Am, B, B/D#, B7, C#7, C#m, C#m7...
# 4          [A*, A11*, A9*, Bm*, Bm11*, Bm6(11)*, D9/F#*, ...
# ...                                                      ...
# 995        [Am, Bm, C, C#m7(5-), C/E, C7M, D, D#º, D/F#, ...
# 996                       [A, C, D, E, E4(7), E7, F, F#m, G]
# 997        [A7, C, D, D/C, D/F#, D5+, D6, D7, Em, Em/F#, ...
# 998                  [Am*, C7M*, Em*, Em6*, Em7M*, G*, G7M*]
# 999                                        [A, Bm, D, Em, G]
#
# [996 rows x 5 columns]

# %%
#df.to_csv('chords.json', index=False)
df.reset_index(drop=True).to_json('songs.json', orient='records')
