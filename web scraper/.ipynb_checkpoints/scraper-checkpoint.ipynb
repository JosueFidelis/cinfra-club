# %%
import requests
import pandas as pd
import json

url = "https://api.cifraclub.com.br/v3/tops?genre=all&" +\
  "instrument=guitar&" +\
  "period=semana&" +\
  "limitSongs=1000&" +\
  "limitArtists=0" +\
  "&offsetSongs=0&" +\
  "offsetArtists=0"

payload={}
headers = {
  'Accept': '*/*',
  'Accept-Language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7,ja-JP;q=0.6,ja;q=0.5',
  'Connection': 'keep-alive',
  'Origin': 'https://www.cifraclub.com.br',
  'Referer': 'https://www.cifraclub.com.br/',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-site',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36',
  'X-Authorization': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..KYuZCi4m_vabxOjgo9R3xF7FxagBQZuKNp9jcxAh5Z3U61KxrhaJb9AeQ9TNYfW0C8WzkK3x0Vj3efIVhCqRCXdDRF9QTNChrt7SOApUxvJmwD9oO5BVx2DK_0M1-xJ3yrgrDIPq_3cjPeVT9erwYo70V9h35UGXue8xE_m2YLiOWH5w8XCd6ZfpHkeScu-OrreX3RgXQamXSLaXdY-alTEogCJVhHkO0qNcvStzdFoAvwLuNfbB3_pkIki3aShjhQ_E6f6kfUxoqhkYZNY8b394IaSrZ5P0S9u81X1LoMA_xSY-PARa5fYnMsNmEWEi57WL9bSrCaG9RkuUJ3dz6w',
  'sec-ch-ua': '"Chromium";v="106", "Google Chrome";v="106", "Not;A=Brand";v="99"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"'
}

response = requests.request("GET", url, headers=headers, data=payload)
# Out:
# {"songs":[{"id":738834,"name":"Deserto","url":"deserto","artist":{"id":321205,"name":"Maria Marçal","url":"maria-marcal","totalPhotos":1,"genre":{"id":30,"name":"Gospel/Religioso","url":"gospelreligioso"},"image":{"50":"https://akamai.sscdn.co/letras/50x50/fotos/5/6/a/8/56a887faf6b464a910cfa5bffbc70f86-tb2.jpg","162":"https://akamai.sscdn.co/letras/162x162/fotos/5/6/a/8/56a887faf6b464a910cfa5bffbc70f86.jpg","250":"https://akamai.sscdn.co/letras/250x250/fotos/5/6/a/8/56a887faf6b464a910cfa5bffbc70f86.jpg","color":"#387ED6"},"headImage":null,"inappropriateContent":{"artist":false,"albuns":false,"photos":false},"songs":null,"externalURLs":{}},"hits":117272,"mod":"revisada"},{"id":475833,"name":"Pode Morar Aqui","url":"pode-morar-aqui","artist":{"id":156142,"name":"Theo Rubia","url":"theo-rubia","totalPhotos":4,"genre":{"id":30,"name":"Gospel/Religioso","url":"gospelreligioso"},"image":{"50":"https://akamai.sscdn.co/letras/50x50/fotos/4/9/d/3/49d36aa9a99f055c75937ec49434a309-tb2.jpg","162":"https://akamai.sscdn.co/letras/162x162/fotos/4/9/d/3/49d36aa9a99f055c75937ec49434a309.jpg","250":"https://akamai.sscdn.co/letras/250x250/fotos/4/9/d/3/49d36aa9a99f055c75937ec49434a309.jpg","color":"#7249B8"},"headImage":null,"inappropriateContent":{"artist":false,"albuns":false,"photos":false},"songs":null,"externalURLs":{}},"hits":105977,"mod":"video-aula"},{"id":730981,"name":"Termina Comigo Antes","url":"termina-comigo-antes","artist":{"id":100182,"name":"Gusttavo Lima","url":"gusttavo-lima","totalPhotos":46,"genre":{"id":9,"name":"Sertanejo","url":"sertanejo"},"image":{"50":"https://akamai.sscdn.co/letras/50x50/fotos/4/3/1/b/431b083745b6d09989f6657950f92b88-tb2.jpg","162":"https://akamai.sscdn.co/letras/162x162/fotos/4/3/1/b/431b083745b6d09989f6657950f92b88.jpg","250":"https://akamai.sscdn.co/letras/250x250/fotos/4/3/1/b/431b083745b6d09989f6657950f92b88.jpg","color":"#4240B1"},"headImage":null,"inappropriateContent":{"artist":false,"albuns":false,"photos":false},"songs":null,"externalURLs":{}},"hits":66309,"mod":"video-aula"},{"id":716152,"name":"A Maior Saudade","url":"a-maior-saudade","artist":{"id":127408,"name":"Henrique e Juliano","url":"henrique-e-juliano","totalPhotos":51,"genre":{"id":9,"name":"Sertanejo","url":"sertanejo"},"image":{"50":"https://akamai.sscdn.co/letras/50x50/fotos/a/f/2/b/af2b3e84979e57aadf45e9cefd68f3cc-tb2.jpg","162":"https://akamai.sscdn.co/letras/162x162/fotos/a/f/2/b/af2b3e84979e57aadf45e9cefd68f3cc.jpg","250":"https://akamai.sscdn.co/letras/250x250/fotos/a/f/2/b/af2b3e84979e57aadf45e9cefd68f3cc.jpg","color":"#C4557F"},"headImage":null,"inappropriateContent":{"artist":false,"albuns":true,"photos":false},"songs":null,"externalURLs":{}},"hits":66257,"mod":"video-aula"},{"id":1906,"name":"Evidências","url":"evidencias","artist":{"id":6956,"name":"Chitãozinho \u0026 Xororó","url":"chitaozinho-e-xororo","totalPhotos":123,"genre":{"id":9,"name":"Sertanejo","url":"sertanejo"},"image":{"50":"https://akamai.sscdn.co/letras/50x50/fotos/2/2/8/2/2282092f52c8a3dc243e837f946a23cc-tb2.jpg","162":"https://akamai.sscdn.co/letras/162x162/fotos/2/2/8/2/2282092f52c8a3dc243e837f946a23cc.jpg","250":"https://akamai.sscdn.co/letras/250x250/fotos/2/2/8/2/2282092f52c8a3dc243e837f946a23cc.jpg","color":"#7FAA33"},"headImage":null,"inappropriateContent":{"artist":false,"albuns":false,"photos":false},"songs":null,"externalURLs":{}},"hits":62154,"mod":"video-aula"},{"id":3219,"name":"Tempo Perdido","url":"tempo-perdido","artist":{"id":19,"name":"Legião Urbana","url":"legiao-urbana","totalPhotos":43,"genre":{"id":2,"name":"Pop Rock","url":"poprock"},"image":{"50":"https://akamai.sscdn.co/letras/50x50/fotos/6/d/6/f/6d6fa97176b534f832b9befb757f0072-tb2.jpg","162":"https://akamai.sscdn.co/letras/162x162/fotos/6/d/6/f/6d6fa97176b534f832b9befb757f0072.jpg","250":"https://akamai.sscdn.co/letras/250x250/fotos/6/d/6/f/6d6fa97176b534f832b9befb757f0072.jpg","color":"#DF7734"},"headImage":null,"inappropriateContent":{"artist":false,"albuns":false,"photos ...

# %%
json_res = response.json()

# %%
df_songs = pd.DataFrame(json_res["songs"])
df_songs
# Out:
#          id                                               name  \
# 0    738834                                            Deserto
# 1    475833                                    Pode Morar Aqui
# 2    730981                               Termina Comigo Antes
# 3    716152                                    A Maior Saudade
# 4      1906                                         Evidências
# ..      ...                                                ...
# 995    4064                                         In The End
# 996    1849                                With Or Without You
# 997  500384  24 Horas de Amor / Só Dá Você Na Minha Vida / ...
# 998  457462                                     Cidade Vizinha
# 999  307905                                     Meu Novo Mundo
#
#                                                    url  \
# 0                                              deserto
# 1                                      pode-morar-aqui
# 2                                 termina-comigo-antes
# 3                                      a-maior-saudade
# 4                                           evidencias
# ..                                                 ...
# 995                                         in-the-end
# 996                                with-or-without-you
# 997  24-horas-de-amor-so-da-voce-na-minha-vida-pens...
# 998                                     cidade-vizinha
# 999                                     meu-novo-mundo
#
#                                                 artist    hits         mod
# 0    {'id': 321205, 'name': 'Maria Marçal', 'url': ...  117272    revisada
# 1    {'id': 156142, 'name': 'Theo Rubia', 'url': 't...  105977  video-aula
# 2    {'id': 100182, 'name': 'Gusttavo Lima', 'url':...   66309  video-aula
# 3    {'id': 127408, 'name': 'Henrique e Juliano', '...   66257  video-aula
# 4    {'id': 6956, 'name': 'Chitãozinho & Xororó', '...   62154  video-aula
# ..                                                 ...     ...         ...
# 995  {'id': 2870, 'name': 'Linkin Park', 'url': 'li...    3006  video-aula
# 996  {'id': 1, 'name': 'U2', 'url': 'u2', 'totalPho...    3004  video-aula
# 997  {'id': 237211, 'name': 'Ícaro e Gilmar', 'url'...    3004
# 998  {'id': 127408, 'name': 'Henrique e Juliano', '...    3003    revisada
# 999  {'id': 6953, 'name': 'Charlie Brown Jr.', 'url...    3003  video-aula
#
# [1000 rows x 6 columns]

# %%
df_songs["pandas_id"] = df_songs.index
df_songs.set_index("pandas_id", inplace=True)
df_songs
# Out:
#                id                                               name  \
# pandas_id
# 0          738834                                            Deserto
# 1          475833                                    Pode Morar Aqui
# 2          730981                               Termina Comigo Antes
# 3          716152                                    A Maior Saudade
# 4            1906                                         Evidências
# ...           ...                                                ...
# 995          4064                                         In The End
# 996          1849                                With Or Without You
# 997        500384  24 Horas de Amor / Só Dá Você Na Minha Vida / ...
# 998        457462                                     Cidade Vizinha
# 999        307905                                     Meu Novo Mundo
#
#                                                          url  \
# pandas_id
# 0                                                    deserto
# 1                                            pode-morar-aqui
# 2                                       termina-comigo-antes
# 3                                            a-maior-saudade
# 4                                                 evidencias
# ...                                                      ...
# 995                                               in-the-end
# 996                                      with-or-without-you
# 997        24-horas-de-amor-so-da-voce-na-minha-vida-pens...
# 998                                           cidade-vizinha
# 999                                           meu-novo-mundo
#
#                                                       artist    hits  \
# pandas_id
# 0          {'id': 321205, 'name': 'Maria Marçal', 'url': ...  117272
# 1          {'id': 156142, 'name': 'Theo Rubia', 'url': 't...  105977
# 2          {'id': 100182, 'name': 'Gusttavo Lima', 'url':...   66309
# 3          {'id': 127408, 'name': 'Henrique e Juliano', '...   66257
# 4          {'id': 6956, 'name': 'Chitãozinho & Xororó', '...   62154
# ...                                                      ...     ...
# 995        {'id': 2870, 'name': 'Linkin Park', 'url': 'li...    3006
# 996        {'id': 1, 'name': 'U2', 'url': 'u2', 'totalPho...    3004
# 997        {'id': 237211, 'name': 'Ícaro e Gilmar', 'url'...    3004
# 998        {'id': 127408, 'name': 'Henrique e Juliano', '...    3003
# 999        {'id': 6953, 'name': 'Charlie Brown Jr.', 'url...    3003
#
#                   mod
# pandas_id
# 0            revisada
# 1          video-aula
# 2          video-aula
# 3          video-aula
# 4          video-aula
# ...               ...
# 995        video-aula
# 996        video-aula
# 997
# 998          revisada
# 999        video-aula
#
# [1000 rows x 6 columns]

# %%
df_artist = pd.json_normalize(df_songs.artist)
df_artist
# Out:
#          id                  name                   url  totalPhotos  \
# 0    321205          Maria Marçal          maria-marcal            1
# 1    156142            Theo Rubia            theo-rubia            4
# 2    100182         Gusttavo Lima         gusttavo-lima           46
# 3    127408    Henrique e Juliano    henrique-e-juliano           51
# 4      6956  Chitãozinho & Xororó  chitaozinho-e-xororo          123
# ..      ...                   ...                   ...          ...
# 995    2870           Linkin Park           linkin-park           86
# 996       1                    U2                    u2           53
# 997  237211        Ícaro e Gilmar        icaro-e-gilmar            2
# 998  127408    Henrique e Juliano    henrique-e-juliano           51
# 999    6953     Charlie Brown Jr.      charlie-brown-jr           45
#
#     headImage songs  genre.id        genre.name        genre.url  \
# 0        None  None      30.0  Gospel/Religioso  gospelreligioso
# 1        None  None      30.0  Gospel/Religioso  gospelreligioso
# 2        None  None       9.0         Sertanejo        sertanejo
# 3        None  None       9.0         Sertanejo        sertanejo
# 4        None  None       9.0         Sertanejo        sertanejo
# ..        ...   ...       ...               ...              ...
# 995      None  None       3.0     Rock and Roll        rock-roll
# 996      None  None       2.0          Pop Rock          poprock
# 997      None  None       9.0         Sertanejo        sertanejo
# 998      None  None       9.0         Sertanejo        sertanejo
# 999      None  None       2.0          Pop Rock          poprock
#
#                                               image.50  \
# 0    https://akamai.sscdn.co/letras/50x50/fotos/5/6...
# 1    https://akamai.sscdn.co/letras/50x50/fotos/4/9...
# 2    https://akamai.sscdn.co/letras/50x50/fotos/4/3...
# 3    https://akamai.sscdn.co/letras/50x50/fotos/a/f...
# 4    https://akamai.sscdn.co/letras/50x50/fotos/2/2...
# ..                                                 ...
# 995  https://akamai.sscdn.co/letras/50x50/fotos/f/9...
# 996  https://akamai.sscdn.co/letras/50x50/fotos/4/5...
# 997  https://akamai.sscdn.co/letras/50x50/fotos/d/c...
# 998  https://akamai.sscdn.co/letras/50x50/fotos/a/f...
# 999  https://akamai.sscdn.co/letras/50x50/fotos/8/a...
#
#                                              image.162  \
# 0    https://akamai.sscdn.co/letras/162x162/fotos/5...
# 1    https://akamai.sscdn.co/letras/162x162/fotos/4...
# 2    https://akamai.sscdn.co/letras/162x162/fotos/4...
# 3    https://akamai.sscdn.co/letras/162x162/fotos/a...
# 4    https://akamai.sscdn.co/letras/162x162/fotos/2...
# ..                                                 ...
# 995  https://akamai.sscdn.co/letras/162x162/fotos/f...
# 996  https://akamai.sscdn.co/letras/162x162/fotos/4...
# 997  https://akamai.sscdn.co/letras/162x162/fotos/d...
# 998  https://akamai.sscdn.co/letras/162x162/fotos/a...
# 999  https://akamai.sscdn.co/letras/162x162/fotos/8...
#
#                                              image.250 image.color  \
# 0    https://akamai.sscdn.co/letras/250x250/fotos/5...     #387ED6
# 1    https://akamai.sscdn.co/letras/250x250/fotos/4...     #7249B8
# 2    https://akamai.sscdn.co/letras/250x250/fotos/4...     #4240B1
# 3    https://akamai.sscdn.co/letras/250x250/fotos/a...     #C4557F
# 4    https://akamai.sscdn.co/letras/250x250/fotos/2...     #7FAA33
# ..                                                 ...         ...
# 995  https://akamai.sscdn.co/letras/250x250/fotos/f...     #E8A925
# 996  https://akamai.sscdn.co/letras/250x250/fotos/4...     #FF7700
# 997  https://akamai.sscdn.co/letras/250x250/fotos/d...     #C43A3A
# 998  https://akamai.sscdn.co/letras/250x250/fotos/a...     #C4557F
# 999  https://akamai.sscdn.co/letras/250x250/fotos/8...     #AAA833
#
#      inappropriateContent.artist  inappropriateContent.albuns  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# 3                          False                         True
# 4                          False                        False
# ..                           ...                          ...
# 995                        False                        False
# 996                        False                        False
# 997                        False                        False
# 998                        False                         True
# 999                        False                        False
#
#      inappropriateContent.photos  genre
# 0                          False    NaN
# 1                          False    NaN
# 2                          False    NaN
# 3                          False    NaN
# 4                          False    NaN
# ..                           ...    ...
# 995                        False    NaN
# 996                        False    NaN
# 997                        False    NaN
# 998                        False    NaN
# 999                        False    NaN
#
# [1000 rows x 17 columns]

# %%
df_artist["pandas_id"] = df_artist.index
df_artist.set_index("pandas_id", inplace=True)
df_artist.drop(columns=[
    "id", \
    "image.50", \
    "image.250", \
    "image.162", \
    "headImage", \
    "genre.id", \
    "songs", \
    "totalPhotos",\
    "inappropriateContent.artist",\
    "inappropriateContent.photos", \
    "inappropriateContent.albuns", \
    "image.color", \
], inplace=True)
df_artist
# Out:
#                            name                   url        genre.name  \
# pandas_id
# 0                  Maria Marçal          maria-marcal  Gospel/Religioso
# 1                    Theo Rubia            theo-rubia  Gospel/Religioso
# 2                 Gusttavo Lima         gusttavo-lima         Sertanejo
# 3            Henrique e Juliano    henrique-e-juliano         Sertanejo
# 4          Chitãozinho & Xororó  chitaozinho-e-xororo         Sertanejo
# ...                         ...                   ...               ...
# 995                 Linkin Park           linkin-park     Rock and Roll
# 996                          U2                    u2          Pop Rock
# 997              Ícaro e Gilmar        icaro-e-gilmar         Sertanejo
# 998          Henrique e Juliano    henrique-e-juliano         Sertanejo
# 999           Charlie Brown Jr.      charlie-brown-jr          Pop Rock
#
#                  genre.url  genre
# pandas_id
# 0          gospelreligioso    NaN
# 1          gospelreligioso    NaN
# 2                sertanejo    NaN
# 3                sertanejo    NaN
# 4                sertanejo    NaN
# ...                    ...    ...
# 995              rock-roll    NaN
# 996                poprock    NaN
# 997              sertanejo    NaN
# 998              sertanejo    NaN
# 999                poprock    NaN
#
# [1000 rows x 5 columns]

# %%
df_songs.drop(columns=["artist", "id", "hits"], inplace=True) 

df = pd.merge(df_songs, df_artist, on="pandas_id", suffixes=('_song', '_artist'))
df
# Out:
#                                                    name_song  \
# pandas_id
# 0                                                    Deserto
# 1                                            Pode Morar Aqui
# 2                                       Termina Comigo Antes
# 3                                            A Maior Saudade
# 4                                                 Evidências
# ...                                                      ...
# 995                                               In The End
# 996                                      With Or Without You
# 997        24 Horas de Amor / Só Dá Você Na Minha Vida / ...
# 998                                           Cidade Vizinha
# 999                                           Meu Novo Mundo
#
#                                                     url_song         mod  \
# pandas_id
# 0                                                    deserto    revisada
# 1                                            pode-morar-aqui  video-aula
# 2                                       termina-comigo-antes  video-aula
# 3                                            a-maior-saudade  video-aula
# 4                                                 evidencias  video-aula
# ...                                                      ...         ...
# 995                                               in-the-end  video-aula
# 996                                      with-or-without-you  video-aula
# 997        24-horas-de-amor-so-da-voce-na-minha-vida-pens...
# 998                                           cidade-vizinha    revisada
# 999                                           meu-novo-mundo  video-aula
#
#                     name_artist            url_artist        genre.name  \
# pandas_id
# 0                  Maria Marçal          maria-marcal  Gospel/Religioso
# 1                    Theo Rubia            theo-rubia  Gospel/Religioso
# 2                 Gusttavo Lima         gusttavo-lima         Sertanejo
# 3            Henrique e Juliano    henrique-e-juliano         Sertanejo
# 4          Chitãozinho & Xororó  chitaozinho-e-xororo         Sertanejo
# ...                         ...                   ...               ...
# 995                 Linkin Park           linkin-park     Rock and Roll
# 996                          U2                    u2          Pop Rock
# 997              Ícaro e Gilmar        icaro-e-gilmar         Sertanejo
# 998          Henrique e Juliano    henrique-e-juliano         Sertanejo
# 999           Charlie Brown Jr.      charlie-brown-jr          Pop Rock
#
#                  genre.url  genre
# pandas_id
# 0          gospelreligioso    NaN
# 1          gospelreligioso    NaN
# 2                sertanejo    NaN
# 3                sertanejo    NaN
# 4                sertanejo    NaN
# ...                    ...    ...
# 995              rock-roll    NaN
# 996                poprock    NaN
# 997              sertanejo    NaN
# 998              sertanejo    NaN
# 999                poprock    NaN
#
# [1000 rows x 8 columns]
